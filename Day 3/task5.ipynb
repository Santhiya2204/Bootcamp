# %%
pip install matplotlib pandas seaborn ipywidgets
# Out:
# Requirement already satisfied: matplotlib in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (3.10.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pandas in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Requirement already satisfied: seaborn in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (0.13.2)
# Collecting ipywidgets
#   Using cached ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets) (8.29.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets)
#   Using cached widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets)
#   Using cached jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: decorator in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: colorama in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\santh\appdata\local\programs\python\python313\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Using cached ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Using cached jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
# ...
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB ? eta -:--:--
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Exception:
# Traceback (most recent call last):
#   File "c:\Users\santh\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "c:\Users\santh\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\urllib3\response.py", line 561, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#            ~~~~~~~~~~~~~^^^^^
#   File "c:\Users\santh\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\urllib3\response.py", line 527, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#            ~~~~~~~~~~~~~^^^^^
#   File "c:\Users\santh\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 98, in read
#     data: bytes = self.__fp.read(amt)
#                   ~~~~~~~~~~~~~~^^^^^
#   File "c:\Users\santh\AppData\Local\Programs\Python\Python313\Lib\http\client.py", line 479, in read
#     s = self.fp.read(amt)
#   File "c:\Users\santh\AppData\Local\Programs\Python\Python313\Lib\socket.py", line 719, in readinto
#     return self._sock.recv_into(b)
#            ~~~~~~~~~~~~~~~~~~~~^^^
#   File "c:\Users\santh\AppData\Local\Programs\Python\Python313\Lib\ssl.py", line 1304, in recv_into
#     return self.read(nbytes, buffer)
#            ~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "c:\Users\santh\AppData\Local\Programs\Python\Python313\Lib\ssl.py", line 1138, in read
#     return self._sslobj.read(len, buffer)
#            ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\santh\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\cli\base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#   File "c:\Users\santh\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\cli\base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#            ~~~~~~~~^^^^^^^^^^^^^^^
#   File "c:\Users\santh\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\cli\req_command.py", line 67, in wrapper
#     return func(self, options, args)
#   File "c:\Users\santh\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\commands\install.py", line 379, in run
#     requirement_set = resolver.resolve(
#         reqs, check_supported_wheels=not options.target_dir
#     )
#   File "c:\Users\santh\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 179, in resolve
#     self.factory.preparer.prepare_linked_requirements_more(reqs)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\santh\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\operations\prepare.py", line 554, in prepare_linked_requirements_more
#     self._complete_partial_requirements(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         partially_downloaded_reqs,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#         parallel_builds=parallel_builds,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\santh\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\operations\prepare.py", line 469, in _complete_partial_requirements
#     for link, (filepath, _) in batch_download:
#                                ^^^^^^^^^^^^^^
#   File "c:\Users\santh\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\network\download.py", line 184, in __call__
#     for chunk in chunks:
#                  ^^^^^^
#   File "c:\Users\santh\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\cli\progress_bars.py", line 55, in _rich_progress_bar
#     for chunk in iterable:
#                  ^^^^^^^^
#   File "c:\Users\santh\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\network\utils.py", line 65, in response_chunks
#     for chunk in response.raw.stream(
#                  ~~~~~~~~~~~~~~~~~~~^
#         chunk_size,
#         ^^^^^^^^^^^
#     ...<22 lines>...
#         decode_content=False,
#         ^^^^^^^^^^^^^^^^^^^^^
#     ):
#     ^
#   File "c:\Users\santh\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\urllib3\response.py", line 622, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "c:\Users\santh\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\urllib3\response.py", line 560, in read
#     with self._error_catcher():
#          ~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\santh\AppData\Local\Programs\Python\Python313\Lib\contextlib.py", line 162, in __exit__
#     self.gen.throw(value)
#     ~~~~~~~~~~~~~~^^^^^^^
#   File "c:\Users\santh\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\urllib3\response.py", line 443, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import ipywidgets as widgets
from ipywidgets import interactive

data = {
    'Country': ['USA', 'Canada', 'Germany', 'Japan', 'India', 'Brazil'],
    'Income': [60000, 50000, 55000, 40000, 3000, 9000],  
    'Life Expectancy': [79, 82, 81, 84, 70, 75],  
    'Year': [2020, 2020, 2020, 2020, 2020, 2020]
}

df = pd.DataFrame(data)

def plot_bubble_chart(selected_year):
    
    filtered_data = df[df['Year'] == selected_year]

    plt.figure(figsize=(10, 6))
    sns.scatterplot(x='Income', y='Life Expectancy', data=filtered_data,
                    size='Income', sizes=(50, 200), hue='Country', palette='tab10', legend=False)
    plt.title(f'Life Expectancy vs Income ({selected_year})', fontsize=16)
    plt.xlabel('Income (USD)', fontsize=12)
    plt.ylabel('Life Expectancy (Years)', fontsize=12)
    plt.show()
year_selector = widgets.Dropdown(
    options=[2020, 2021, 2022],  
    value=2020,  
    description='Year:',
)
interactive_plot = interactive(plot_bubble_chart, selected_year=year_selector)
output = interactive_plot.children[-1]
output.layout.height = '400px'
interactive_plot
# Out:
# interactive(children=(Dropdown(description='Year:', options=(2020, 2021, 2022), value=2020), Output(layout=Lay…
